# %%
#OpenCV import 및 원본 영상 출력

import numpy as np
import cv2 
from google.colab.patches import cv2_imshow

img = cv2.imread("데이터마이닝\\데이터마이닝 17_컴퓨터 비전 및 전처리 과정의 이해 (CNN 기초)_실습 파일\\lena256_rgb.jpg")
print("원본 영상")
cv2_imshow(img)
# Out:
# 원본 영상
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_24604/611690305.py in <cell line: 0>()
#       7 img = cv2.imread("데이터마이닝\\데이터마이닝 17_컴퓨터 비전 및 전처리 과정의 이해 (CNN 기초)_실습 파일\\lena256_rgb.jpg")
#       8 print("원본 영상")
# ----> 9 cv2_imshow(img)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
#그레이 영상 출력

im_gray= cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print("그레이 영상")
cv2_imshow(im_gray)

# %%
# 영상의 덧셈/뺄셈 연산

num=100

im_add =cv2.add(im_gray, num)
print("덧셈/뺄셈 연산")
cv2_imshow(im_add)

# %%
#역변환 영상

im_sub =cv2.subtract(255,im_gray)
print("역변환")
cv2_imshow(im_sub)

# %%
#임계값 th를 기준으로 이진화한 영상

th= 100

th, im_th = cv2.threshold(im_gray, th, 255, cv2.THRESH_BINARY)
print("이진 영상")
cv2_imshow(im_th)

# %%
#영상의 확대 축소(원하는 크기를 입력하세요), 이웃 화소 보간법

#열의 수 입력
r=800

#행의 수 입력
c=500

im_resize1 = cv2.resize(im_gray, dsize=(r, c), interpolation=cv2.INTER_NEAREST)
print("영상 크기 조절(이웃 화소 보간법)")
cv2_imshow(im_resize1)

# %%
#영상의 확대 축소(원하는 크기를 입력하세요), 양선형 보간법

#열의 수 입력
r=800

#행의 수 입력
c=500


im_resize2 = cv2.resize(im_gray, dsize=(r, c), interpolation=cv2.INTER_LINEAR)
print("영상 크기 조절(양선형 보간법)")
cv2_imshow(im_resize2)
