# %%
from sklearn.linear_model import Perceptron

# <학습데이터의 입력과 정답> 입력
X = [[0,0],[0,1],[1,0],[1,1]]
y = [0, 0, 0, 1]

# 퍼셉트론을 생성한다.
clf = Perceptron()

# 학습을 수행한다. 
clf.fit(X, y)

# 테스트를 수행한다. 
test = [1, 1]
print(clf.predict([test]))
